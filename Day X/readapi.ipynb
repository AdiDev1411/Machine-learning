# %%
import pandas as pd
import requests

# %%
res = requests.get('https://cdn.jsdelivr.net/npm/@fawazahmed0/currency-api@latest/v1/currencies/usd.json')

# %%
res.json()
# Out:
# {'date': '2025-02-16',
#  'usd': {'1inch': 3.74438254,
#   'aave': 0.0039646876,
#   'ada': 1.28406776,
#   'aed': 3.6725,
#   'afn': 73.35139979,
#   'agix': 2.98336997,
#   'akt': 0.52930552,
#   'algo': 3.55380019,
#   'all': 94.99396876,
#   'amd': 396.51720278,
#   'amp': 176.6362254,
#   'ang': 1.78750041,
#   'aoa': 912.09786749,
#   'ape': 1.40192077,
#   'apt': 0.16683355,
#   'ar': 0.10973937,
#   'arb': 2.10840608,
#   'ars': 1056.00156333,
#   'atom': 0.20822621,
#   'ats': 13.1100163,
#   'aud': 1.57447466,
#   'avax': 0.039489718,
#   'awg': 1.79,
#   'axs': 0.22846102,
#   'azm': 8500.00023305,
#   'azn': 1.70000005,
#   'bake': 4.49854942,
#   'bam': 1.86340146,
#   'bat': 5.47606476,
#   'bbd': 2,
#   'bch': 0.0029957035,
#   'bdt': 121.52128819,
#   'bef': 38.43351864,
#   'bgn': 1.86340146,
#   'bhd': 0.376,
#   'bif': 2914.65088218,
#   'bmd': 1,
#   'bnb': 0.0015120906,
#   'bnd': 1.33924435,
#   'bob': 6.93494783,
#   'brl': 5.7048529,
#   'bsd': 1,
# ...

# %%
pd.DataFrame(res.json())
# Out:
#              date           usd
# 1inch  2025-02-16      3.744383
# aave   2025-02-16      0.003965
# ada    2025-02-16      1.284068
# aed    2025-02-16      3.672500
# afn    2025-02-16     73.351400
# ...           ...           ...
# zmk    2025-02-16  28248.761571
# zmw    2025-02-16     28.248762
# zwd    2025-02-16    361.900000
# zwg    2025-02-16     26.817727
# zwl    2025-02-16  67010.103110
#
# [339 rows x 2 columns]
