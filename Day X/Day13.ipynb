# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\ADITYA\Desktop\100DaysOf ML\DataSets\carprices2.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Age(yrs)'],df['Mileage'],c=df['Sell Price($)'])
plt.xlabel('Age')
plt.ylabel('Mileage')
# Out:
# Text(0, 0.5, 'Mileage')

# %%
X = df[['Age(yrs)', 'Mileage']]
X
# Out:
#     Age(yrs)  Mileage
# 0          6    69000
# 1          3    35000
# 2          5    57000
# 3          2    22500
# 4          4    46000
# 5          5    59000
# 6          5    52000
# 7          6    72000
# 8          8    91000
# 9          6    67000
# 10         7    83000
# 11         7    79000
# 12         5    59000
# 13         4    58780
# 14         7    82450
# 15         3    25400
# 16         2    28000
# 17         5    69000
# 18         8    87600
# 19         5    52000

# %%
Y = df['Sell Price($)']
Y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3)

# %%
X_train
# Out:
#     Age(yrs)  Mileage
# 11         7    79000
# 8          8    91000
# 16         2    28000
# 5          5    59000
# 15         3    25400
# 7          6    72000
# 0          6    69000
# 3          2    22500
# 19         5    52000
# 4          4    46000
# 17         5    69000
# 6          5    52000
# 2          5    57000
# 9          6    67000

# %%
X_test
# Out:
#     Age(yrs)  Mileage
# 10         7    83000
# 1          3    35000
# 12         5    59000
# 13         4    58780
# 18         8    87600
# 14         7    82450

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train
# Out:
# array([[ 1.24222352,  1.14777955],
#        [ 1.84191763,  1.75587468],
#        [-1.75624704, -1.43662473],
#        [ 0.04283529,  0.13428767],
#        [-1.15655293, -1.56837868],
#        [ 0.64252941,  0.79305739],
#        [ 0.64252941,  0.64103361],
#        [-1.75624704, -1.715335  ],
#        [ 0.04283529, -0.22043448],
#        [-0.55685882, -0.52448205],
#        [ 0.04283529,  0.64103361],
#        [ 0.04283529, -0.22043448],
#        [ 0.04283529,  0.03293849],
#        [ 0.64252941,  0.53968442]])

# %%
Y_test
# Out:
# 10    18700
# 1     34000
# 12    26000
# 13    27500
# 18    12800
# 14    19400
# Name: Sell Price($), dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train,Y_train)

clf.predict(X_test)
y_predict = clf.predict(X_test)
#y_predict = clf.predict(X_test)

# %%
import pickle
pickle.dump(clf,open(r'C:\Users\ADITYA\Desktop\100DaysOf ML\CollectionModel\model.pkl','wb'))

# %%
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64
