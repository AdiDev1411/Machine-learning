# %% [markdown]
# <a href="https://colab.research.google.com/github/AdiDev1411/Machine-learning/blob/main/GridSearchCV_%2B_Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
print(X.shape , y.shape)
# Out:
# (303, 13) (303,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , random_state=42 ,test_size= 0.2)

# %%
X_train.shape
# Out:
# (242, 13)

# %%
from ast import Import
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier , RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression()
svc = SVC()
gb = GradientBoostingClassifier()
rf = RandomForestClassifier()

# %%
lr.fit( X_train , y_train)
y_pred  = lr.predict(X_test)
print("Accuracy score : " , accuracy_score(y_test , y_pred))
# Out:
# Accuracy score :  0.8852459016393442

# %%
svc.fit( X_train , y_train)
y_pred  = svc.predict(X_test)
print("Accuracy score : " , accuracy_score(y_test , y_pred))
# Out:
# Accuracy score :  0.7049180327868853

# %%
gb.fit( X_train , y_train)
y_pred  = gb.predict(X_test)
print("Accuracy score : " , accuracy_score(y_test , y_pred))
# Out:
# Accuracy score :  0.7704918032786885

# %%
rf.fit( X_train , y_train)
y_pred  = rf.predict(X_test)
print("Accuracy score : " , accuracy_score(y_test , y_pred))
# Out:
# Accuracy score :  0.8524590163934426

# %%
rf = RandomForestClassifier(max_samples=0.75 , random_state=42)
rf.fit( X_train , y_train)
y_pred  = rf.predict(X_test)
print("Accuracy score : " , accuracy_score(y_test , y_pred))
# Out:
# Accuracy score :  0.9016393442622951

# %% [markdown]
# # **GridSearchCV**

# %%
from sklearn.model_selection import GridSearchCV

# %%
n_estimators = [20 , 40 ,60 , 120 ]

max_depth = [2 , 3 ,5 ]

max_features = [0.2 , 0.4 , 0.6 , 0.8]

max_samples = [0.2 , 0.5 , 0.75]

# %%
param_grid = {
    'n_estimators' : n_estimators,
    'max_depth' : max_depth,
    'max_features' : max_features,
    'max_samples' : max_samples
}

print(param_grid)
# Out:
# {'n_estimators': [20, 40, 60, 120], 'max_depth': [2, 3, 5], 'max_features': [0.2, 0.4, 0.6, 0.8], 'max_samples': [0.2, 0.5, 0.75]}

# %%
rf = RandomForestClassifier()

# %%
rf_grid = GridSearchCV(estimator=rf , param_grid=param_grid , cv=5 , verbose=2 , n_jobs=-1 )

# %%
rf_grid.fit(X_train , y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5],
#                          'max_features': [0.2, 0.4, 0.6, 0.8],
#                          'max_samples': [0.2, 0.5, 0.75],
#                          'n_estimators': [20, 40, 60, 120]},
#              verbose=2)

# %%
rf_grid.best_params_
# Out:
# {'max_depth': 5, 'max_features': 0.6, 'max_samples': 0.2, 'n_estimators': 20}

# %%
rf_grid.best_score_
# Out:
# np.float64(0.8427721088435375)
