# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])
df
# Out:
#      FireplaceQu GarageQual  SalePrice
# 0            NaN         TA     208500
# 1             TA         TA     181500
# 2             TA         TA     223500
# 3             Gd         TA     140000
# 4             TA         TA     250000
# ...          ...        ...        ...
# 1455          TA         TA     175000
# 1456          TA         TA     210000
# 1457          Gd         TA     266500
# 1458         NaN         TA     142125
# 1459         NaN         TA     147500
#
# [1460 rows x 3 columns]

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
df['GarageQual'].mode()
# Out:
# 0    TA
# Name: GarageQual, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde',ax=ax)
df[df['GarageQual'].isnull()]['SalePrice'].plot(kind='kde',ax=ax)
# Out:
# <Axes: ylabel='Density'>

# %%
temp = df[df['GarageQual']=='TA']['SalePrice']

# %%
df['GarageQual'].fillna(df['GarageQual'].mode,inplace=True)
df.isnull().sum()
# Out:
# FireplaceQu    690
# GarageQual       0
# SalePrice        0
# dtype: int64

# %%
df['GarageQual_mode'] = df['GarageQual']
df['GarageQual_mode'].fillna(df['GarageQual_mode'].mode)
# Out:
# 0       TA
# 1       TA
# 2       TA
# 3       TA
# 4       TA
#         ..
# 1455    TA
# 1456    TA
# 1457    TA
# 1458    TA
# 1459    TA
# Name: GarageQual_mode, Length: 1460, dtype: object

# %%
df['GarageQual_mode'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual_mode'>

# %%
fig = plt.figure()

ax = fig.add_subplot(111)

df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde')
df[df['GarageQual_mode']=='TA']['SalePrice'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # With FireQual

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
df['FireplaceQu'].mode()
# Out:
# 0    Gd
# Name: FireplaceQu, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde')
df[df['FireplaceQu'].isnull()]['SalePrice'].plot(kind='kde')
labels = ['Houses with Gd','Houses with NA']
ax.legend(labels)

# %%
temp = df[df['FireplaceQu']=='Gd']['SalePrice']

# %%
df['FireplaceQu'].fillna(df['FireplaceQu'].mode()[0],inplace=True)

df.isnull().sum()
# Out:
# FireplaceQu        0
# GarageQual         0
# SalePrice          0
# GarageQual_mode    0
# dtype: int64

# %%
fig = plt.figure()
fig.add_subplot(111)

temp.plot(kind='kde')
df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>
